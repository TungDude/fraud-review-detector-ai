# %% [markdown]
# # Data Synthesis for training and database populate

# %% [markdown]
#   ## Purpose: MVP Dataset Creation
#   This notebook generates datasets for:
#    1. ML Training
#    2. LM Finetuning
#    3. Database
#
#   Dataset Structure & Content
#
#    | Dataset | Attributes (Columns) | Values (Rows) |
#    | :--- | :--- | :--- |
#    | **1. ML Training** | Full Set | Reference Set |
#    | **2. LM Finetuning** | **Subset** of Dataset 1 | **Same** as Dataset 1 |
#    | **3. Database** | **Same** as Dataset 1 | **Different** from others |

# %% [markdown]
# # Implementation
